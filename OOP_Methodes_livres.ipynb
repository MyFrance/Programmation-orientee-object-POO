# %%
class Livre:
    def __init__(self, nom, nombre_de_pages, livre):
        self.nom = nom
        self.nombre_de_pages = nombre_de_pages
        self.livre = livre

# %%
livre1 = Livre("Harry Potter", 300, 10.99)
print(livre1.nom)
# Out:
# Harry Potter

# %%
livre2 = Livre("Le Seigneur des Anneaux", 400, 13.99)
print(livre2.nom)
# Out:
# Le Seigneur des Anneaux
