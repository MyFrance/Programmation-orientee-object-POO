# %%
class MobilPhone():
    discount = 10
    sno = 0
    def __init__(self, name, price):
        MobilPhone.sno +=1
        self.sno = MobilPhone.sno
        self.name = name
        self.price = price
        
    def Applydiscount(self):
        discountAmount = (self.price * self.discount)/100
        finalPrice = self.price - discountAmount
        return finalPrice

# %%
galaxyS9 = MobilPhone("galaxyS9", 800)

# %%
#Afficher les attributs de galaxyS9
galaxyS9.__dict__
# Out:
# {'sno': 1, 'name': 'galaxyS9', 'price': 800}

# %%
#Ajouter les attribut de galaxyS9
galaxyS9.bluetooth = "yes"

# %%
galaxyS9.photo = "yes"
galaxyS9.__dict__
# Out:
# {'sno': 1,
#  'name': 'galaxyS9',
#  'price': 800,
#  'bluetooth': 'yes',
#  'photo': 'yes'}

# %%
galaxyS9.Applydiscount()
# Out:
# 720.0

# %%
galaxys10 = MobilPhone("galaxys10", 1100)
galaxys10.price
# Out:
# 1100

# %%
galaxys10.discount = 8
galaxys10.__dict__
# Out:
# {'sno': 2, 'name': 'galaxys10', 'price': 1100, 'discount': 8}

# %%
galaxys10.Applydiscount()
# Out:
# 1012.0
