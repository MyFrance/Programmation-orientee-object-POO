# %%
class Student: 
    total_marks = 1000
    def __init__(self, name, age, marks):
        self.name = name
        self.age = age
        self.marks = marks
        self.total_marks = Student.total_marks

# %%
S1 = Student("Mathieu", 25, 19)
S1.total_marks
# Out:
# 1000
